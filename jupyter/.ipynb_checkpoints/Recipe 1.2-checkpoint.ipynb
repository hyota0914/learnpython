# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('./test.csv', index_col='date',parse_dates=True, dayfirst=True)
df
# Out:
#                              market type   price  amount  fee  bonus  comment
# date
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506585  0.0046    0    0.2      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506790  0.3250    0   16.4      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506830  0.0197    0    0.9      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506830  0.0121    0    0.6      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506845  0.0001    0    0.0      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506845  0.2057    0   10.4      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506850  0.2000    0   10.1      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506860  0.0500    0    2.5      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  507150  0.0050    0    0.2      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  507210  0.0050    0    0.2      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  507280  0.2692    0   13.6      NaN
# ...

# %%
df.head(5)
# Out:
#                              market type   price  amount  fee  bonus  comment
# date
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506585  0.0046    0    0.2      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506790  0.3250    0   16.4      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506830  0.0197    0    0.9      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506830  0.0121    0    0.6      NaN
# 2017-08-30 10:42:12.673782  btc_jpy  bid  506845  0.0001    0    0.0      NaN

# %%
df.describe()
# Out:
#                price     amount   fee      bonus  comment
# count      48.000000  48.000000  48.0  48.000000      0.0
# mean   508375.729167   0.115173   0.0   5.816667      NaN
# std      2186.605012   0.293304   0.0  14.914056      NaN
# min    506585.000000   0.000100   0.0   0.000000      NaN
# 25%    506992.500000   0.004825   0.0   0.200000      NaN
# 50%    507107.500000   0.011700   0.0   0.500000      NaN
# 75%    510066.250000   0.050000   0.0   2.500000      NaN
# max    513800.000000   1.669400   0.0  84.600000      NaN

# %%
df[['price']].plot()

# %%
df.groupby('date').sum()
# Out:
#                               price  amount  fee  bonus  comment
# date
# 2017-08-30 10:42:12.673782  5576075  1.0964    0   55.1      NaN
# 2017-08-30 10:43:43.584908  6085990  0.7177    0   35.9      NaN
# 2017-09-04 16:33:45.559971  5578055  1.8142    0   91.4      NaN
# 2017-09-04 19:30:16.253568  7161915  1.9000    0   96.8      NaN
